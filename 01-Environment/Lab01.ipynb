# %% [markdown]
# # 패키지 설치 확인
#
# numpy, pandas, matplotlib, jupyterlab이 올바르게 설치되었는지 확인합니다.

# %% [markdown]
# ## 1. 버전 확인

# %%
import numpy as np
import pandas as pd
import matplotlib
import jupyterlab

print(f"numpy     : {np.__version__}")
print(f"pandas    : {pd.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"jupyterlab: {jupyterlab.__version__}")
# Out:
# numpy     : 2.4.2
# pandas    : 3.0.1
# matplotlib: 3.10.8
# jupyterlab: 4.5.5

# %% [markdown]
# ## 2. NumPy

# %%
a = np.array([1, 2, 3, 4, 5])
print("배열:", a)
print("평균:", a.mean())
print("표준편차:", a.std())

b = np.random.randn(3, 3)
print("\n3x3 랜덤 행렬:\n", b)

# %% [markdown]
# ## 3. Pandas

# %%
df = pd.DataFrame({
    "이름": ["Alice", "Bob", "Charlie", "Diana"],
    "나이": [25, 30, 35, 28],
    "점수": [88.5, 92.0, 79.5, 95.0]
})

print(df)
print("\n기술 통계:")
df.describe()

# %% [markdown]
# ## 4. Matplotlib

# %%
import matplotlib.pyplot as plt

# macOS 한글 폰트 설정
plt.rcParams["font.family"] = "AppleGothic"
plt.rcParams["axes.unicode_minus"] = False  # 마이너스 기호 깨짐 방지

x = np.linspace(0, 2 * np.pi, 100)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(x, np.sin(x), label="sin")
axes[0].plot(x, np.cos(x), label="cos")
axes[0].set_title("Sin & Cos")
axes[0].legend()
axes[0].grid(True)

axes[1].bar(df["이름"], df["점수"], color=["steelblue", "tomato", "seagreen", "orange"])
axes[1].set_title("점수 비교")
axes[1].set_ylabel("점수")

plt.tight_layout()
plt.show()

# %% [markdown]
# 모든 셀이 오류 없이 실행되면 설치가 완료된 것입니다.
